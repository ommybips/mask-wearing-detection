# %%
import cv2
import tensorflow as tf
from tensorflow import keras
from PIL import Image

# %%
# cv2.__version__

# %%
image = r'test1.jpg'
face_cascade = "haarcascade_frontalface_default.xml"

# %%
image_bgr = cv2.imread(image)
image_bw = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)

# %%
face_classifier = cv2.CascadeClassifier(face_cascade)
faces = face_classifier.detectMultiScale(image_bw)

# %%
print(f'There are {len(faces)} faces found.')
# Out:
# There are 0 faces found.

# %%
for face in faces:
    x, y, w, h = face
    cv2.rectangle(image_bgr, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
cv2.imshow("Faces found", image_bgr)
cv2.waitKey(0)
# Out:
# -1

# %%
webcam = cv2.VideoCapture(0)
webcam
# Out:
# <VideoCapture 000001ECAEB2BCF0>

# %%
success, image_bgr = webcam.read()
#print(success, image_bgr)

# %%
face_cascade = "haarcascade_frontalface_default.xml"

# %%
# while True:
 
#     success, image_bgr = webcam.read()
#     image_org = image_bgr.copy()
#     image_bw = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)

#     face_classifier = cv2.CascadeClassifier(face_cascade)
#     faces = face_classifier.detectMultiScale(image_bw)

#     print(f'There are {len(faces)} faces found.')

#     for face in faces:
#         x, y, w, h = face
#         cv2.rectangle(image_bgr, (x, y), (x+w, y+h), (0, 255, 0), 2)
#         image_org[y:y+h,x:x+w]
        
#     cv2.imshow("Faces found", image_bgr)
#     cv2.waitKey(1)

# %%
# count = 9999
# while True:
 
#     success, image_bgr = webcam.read()
#     image_org = image_bgr.copy()
#     image_bw = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)

#     face_classifier = cv2.CascadeClassifier(face_cascade)
#     faces = face_classifier.detectMultiScale(image_bw)

#     print(f'There are {len(faces)} faces found.')

#     for face in faces:
#         x, y, w, h = face
#         cv2.rectangle(image_bgr, (x, y), (x+w, y+h), (0, 255, 0), 2)
#         cv2.imwrite(f'nomask/nomask_{count}.jpg',image_org[y:y+h,x:x+w])
#         count += 1

#     cv2.imshow("Faces found", image_bgr)
#     cv2.waitKey(1)

# %%
import tensorflow.keras
from PIL import Image
from PIL import ImageOps
import numpy as np

# %%
np.set_printoptions(suppress=True)

# %%
model = tensorflow.keras.models.load_model('keras_model.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

# %%
import os
from PIL import Image

curDir = os.getcwd()
fileName = "test1.jpg"
fn = curDir + "\\" + fileName
print(fn)

from os import listdir
from os.path import isfile, join

onlyfiles = [f for f in listdir(curDir) if isfile(join(curDir, f))]
print(onlyfiles)

image = Image.open(fn)
# image.show()
# Out:
# C:\Users\Admin\Senior Project\test1.jpg
# ['a.jpg', 'haarcascade_frontalface_default.xml', 'keras_model.h5', 'labels.txt', 'mask detect.ipynb', 'test1.jpg', 'test2_1080.jpg', 'test_photo.jpg', 'test_photo1.jpg', 'test_photo1080.jpg', 'test_photo360.jpg', 'test_photo720.jpg']

# %%
size = (224, 224)
image = ImageOps.fit(image, size, Image.ANTIALIAS)

# %%
image_array = np.asarray(image)

# %%
image.show()

# %%
normalized_image_array = (image_array.astype(np.float32) / 127.0) - 1

# %%
prediction = model.predict(data)
print(prediction)
# Out:
# [[0.83079165 0.1692083 ]]

# %%
webcam = cv2.VideoCapture(0)
success, image_bgr = webcam.read()

# %%
image_rgb = cv2.cvtColor(image_bgr,cv2.COLOR_BGR2RGB)

# %%
cface_rgb = Image.fromarray(image_rgb[y:y+h,x:x+w])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1712/330498503.py in <module>
# ----> 1 cface_rgb = Image.fromarray(image_rgb[y:y+h,x:x+w])
#
# NameError: name 'y' is not defined

# %%
face_classifier = cv2.CascadeClassifier(face_cascade)
np.set_printoptions(suppress=True)
model = tensorflow.keras.models.load_model('keras_model.h5')
size = (224, 224)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# while True:
#     success, image_bgr = webcam.read()
#     image_org = image_bgr.copy()
#     image_bw = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)
#     image_rgb = cv2.cvtColor(image_bgr,cv2.COLOR_BGR2RGB)
#     faces = face_classifier.detectMultiScale(image_bw)
#     for face in faces:
#         x, y, w, h = face
#         cface_rgb = Image.fromarray(image_rgb[y:y+h,x:x+w])
#         data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
#         image = cface_rgb
#         image = ImageOps.fit(image, size, Image.ANTIALIAS)
#         image_array = np.asarray(image)
#         normalized_image_array = (image_array.astype(np.float32) / 127.0) - 1
#         data[0] = normalized_image_array
#         prediction = model.predict(data)
#         print(prediction)
#         cv2.rectangle(image_bgr, (x, y), (x+w, y+h), (0, 255, 0), 2)
#     cv2.imshow("Mask Detection", image_bgr)
#     cv2.waitKey(1)

# %%
while True:
    success, image_bgr = webcam.read()
    image_org = image_bgr.copy()
    image_bw = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)
    image_rgb = cv2.cvtColor(image_bgr,cv2.COLOR_BGR2RGB)
    faces = face_classifier.detectMultiScale(image_bw)
    for face in faces:
        x, y, w, h = face
        cface_rgb = Image.fromarray(image_rgb[y:y+h,x:x+w])
        data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
        image = cface_rgb
        image = ImageOps.fit(image, size, Image.ANTIALIAS)
        image_array = np.asarray(image)
        normalized_image_array = (image_array.astype(np.float32) / 127.0) - 1
        data[0] = normalized_image_array
        prediction = model.predict(data)
        print(prediction)
        if prediction[0][0] < prediction[0][1]:
            cv2.putText(image_bgr,'Masked',(x,y-7),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,255,0),2)
            cv2.rectangle(image_bgr, (x, y), (x+w, y+h), (0, 255, 0), 2)
            cv2.imwrite(f'nomask/nomask_{count}.jpg',image_org[y:y+h,x:x+w])
            count += 1
        else:
            cv2.putText(image_bgr,'Non-Masked',(x,y-7),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,255),2)
